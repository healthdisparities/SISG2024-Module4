# %% [markdown]
# # Module 4 Session *X* Placeholder Notebook
#
# **Author**: Shashwat Deepali Nagar
# **Date**: May 31, 2024

# %%
# This notebook runs an R kernel

R.Version()
# Out:
# $platform
# [1] "aarch64-apple-darwin20"
#
# $arch
# [1] "aarch64"
#
# $os
# [1] "darwin20"
#
# $system
# [1] "aarch64, darwin20"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "4.0"
#
# $year
# [1] "2024"
#
# $month
# [1] "04"
#
# $day
# [1] "24"
#
# $`svn rev`
# [1] "86474"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.4.0 (2024-04-24)"
#
# $nickname
# [1] "Puppy Cup"
